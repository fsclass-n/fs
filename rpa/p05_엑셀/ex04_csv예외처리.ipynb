# %%
# csv 파일 불러와서 형식 확인하기
import usecsv, re
total = usecsv.opencsv(r'D:\wi\git\fs\rpa\p05_엑셀\popSeoul2023.csv')

# %%
# 예외 처리로 오류 넘어가기
i = ['123!!', '151,767', '11,093', '27394', ''] # i에 빈문자열('') 추가
for j in i:
    if re.search('[a-z가-힝!]', j):
        i[i.index(j)] = j
    else:
        i[i.index(j)] = float(j.replace(',', ''))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[5], line 7
#       3 for j in i:
#       4     if re.search('[a-z가-힝!]', j):
#       5         i[i.index(j)] = j
#       6     else:
# ----> 7         i[i.index(j)] = float(j.replace(',', ''))
#
# ValueError: could not convert string to float: ''
